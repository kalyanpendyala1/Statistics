# %% [markdown]
# **Expected Value:** Probability of event multiplied by amount of times the event happens. Ex. If you take test with 20 multiple choice questions. choices are A,B,C,D. You guess all 'A's. each choice has probability of 25% of success. if you chose all options as A, then 1/4 * 20 = 5. which means you most likely get 5 out of 20 as correct.

# %% [markdown]
# **Mean-Absolute Deviation:** How much they deviate from mean.
#
# sum|observation - mean| / 2

# %% [markdown]
# **Linear Transformation:** A linear transformation is change to a variable charecterized by one  or more of the following,
#
# Adding constant to a variable (y = x+b).
#
# Subtracting a constant from a variable (y=x-b).
#
# Multiplying a variable by a constant (y=x * b).
#
# Dividing the variable by a constant (y = x/b).

# %% [markdown]
# ### How to find Z-Score
#
# **Z-score:** Measures how many standard deviations away from the mean.  If Z-Score is 0, it indicates that point is identical to mean. If Z-Score is 1, it means the point is 1 Standard Deviations away from mean.
#
# Values Right side of the mean, Positive Z-Score. Values left side of the mean - Negative Z-Score.
#
# *Ex: The grades on a chemistry midterm at Springer are roughly symmetric with  μ=67 and SD = 2.0
# William scored 66 on the exam. Find the z-score for William's exam grade. Round to two decimal places*
#
# ![image.png](attachment:image.png)
#
#  Z = (66-67) / 2.0 = -0.5
#
#  That means willian score is -0.5 standard deviations away from the mean.
#
#  If it is a normal distribution, you can also interpret precentage by using z scores table.

# %% [markdown]
# **Density Curve:** Density Curve is a graph that shows probability. Area under the curve is equal to 100% of all the probabilities. Area under the curve is equal to 1. We are forcing area under the curve to be equal to 1 so that we can associate with probability. In density curve, on x variable if we hava a continuous variable, We cant pick a single value. every point has infinte number of possibilities.
#
# EX. Suppose x variable is height from 5.5 inches to 6 inches. We cant pick 5.7 inches from x variable. because it may not be accurately 5.7, it may be 5.69999 or 5.71000001 like that. It is like, picking a nail from a bunch of nails, the bunch is similar to size of earth. Then what is the probability of picking one nail?
#
# If you take one point from the from the infinite number of segments, your probability will be very close to zero. Thats why we are taking area instead of one point. (5.6 >= x >= 5.7).
#
# ![image.png](attachment:image.png)
#
# Right skewed (positive) distribution pulls mean to the right of the median. Left skewed (negative) distribution pulls the mean left side of the median.

# %% [markdown]
# **Emprical Rule of Normal Distribution:** 68% of values are withing 1SD. 95% of values are withing 2SD. 99.7% of values are within 3SD.
#
# **Uniform Distribution:** All values have same probability of occuring.

# %% [markdown]
# **Non-Linear Relationship:** A non linear relationship reflects that each unit change in x variable will not always bring about the same change in Y variable. (Un-Predictable)
#
# **Linear Relationship:** Two quantities are proportional to each other, If you increase one quantity other will increase of decrease.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **Correlation:** Correlation used to test relationship between two variable. When y variable increases x also increases, we can call this correlation as **Positive Correlation**. When y variable tends to decrease and X variable increases we call it **Negative Correlation**.
#
#
# ![image.png](attachment:image.png)
#
# **Correlation Coefficient:** A correlation coefficient is a way to put a value to the relationship. Correlation coefficients have a value of between -1 and 1. A “0” means there is no relationship between the variables at all, while -1 or 1 means that there is a perfect negative or positive correlation

# %% [markdown]
# ### Steps for Calculating r
# We will begin by listing the steps to the calculation of the correlation coefficient. The data we are working with are paired data, each pair of which will be denoted by (xi,yi).
#
# ![image.png](attachment:image.png)
#
# We begin with a few preliminary calculations. The quantities from these calculations will be used in subsequent steps of our calculation of r:
# Calculate x̄, the mean of all of the first coordinates of the data xi.
# Calculate ȳ, the mean of all of the second coordinates of the data yi.
# Calculate s x the sample standard deviation of all of the first coordinates of the data xi.
# Calculate s y the sample standard deviation of all of the second coordinates of the data yi.
# Use the formula (zx)i = (xi – x̄) / s x and calculate a standardized value for each xi.
# Use the formula (zy)i = (yi – ȳ) / s y and calculate a standardized value for each yi.
# Multiply corresponding standardized values: (zx)i(zy)i
# Add the products from the last step together.
# Divide the sum from the previous step by n – 1, where n is the total number of points in our set of paired data. The result of all of this is the correlation coefficient r.
